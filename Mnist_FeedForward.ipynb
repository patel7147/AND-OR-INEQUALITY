# %% [markdown]
# <a href="https://colab.research.google.com/github/patel7147/ROYAL_DL/blob/master/Mnist_FeedForward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras import datasets , layers , models
import matplotlib as plt
from tensorflow.keras.utils import to_categorical

# %%
(train_images , train_labels) , (test_images , test_labels) = datasets.mnist.load_data()
train_images , test_images = train_images/255.0 , test_images/255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
train_images = train_images.reshape(train_images.shape[0],28,28,1)
test_images = test_images.reshape(test_images.shape[0],28,28,1)
print(train_images.shape)
print(test_images.shape)
print(train_images.shape)
print(train_labels.shape)
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000, 28, 28, 1)
# (60000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD , Adam

model = models.Sequential()
model.add(layers.Flatten(input_shape = (28,28,1)))
model.add(Dense(64,activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# ...
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.01),'mean_squared_error' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0140 - accuracy: 0.9107
# Epoch 2/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0116 - accuracy: 0.9349
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0118 - accuracy: 0.9375
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0115 - accuracy: 0.9394
# Epoch 5/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0114 - accuracy: 0.9408
# Epoch 6/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0110 - accuracy: 0.9430
# Epoch 7/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0110 - accuracy: 0.9438
# Epoch 8/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0107 - accuracy: 0.9447
# Epoch 9/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0120 - accuracy: 0.9385
# Epoch 10/100
# ...

# %%
model.compile(Adam(lr=0.01),'categorical_crossentropy' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 11.3696 - accuracy: 0.9689
# Epoch 2/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 4.7855 - accuracy: 0.9658
# Epoch 3/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 2.3373 - accuracy: 0.9526
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.2141 - accuracy: 0.9340
# Epoch 5/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7542 - accuracy: 0.9210
# Epoch 6/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5269 - accuracy: 0.9197
# Epoch 7/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4296 - accuracy: 0.9215
# Epoch 8/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3655 - accuracy: 0.9301
# Epoch 9/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3156 - accuracy: 0.9348
# Epoch 10/100
# ...

# %%
model.compile(SGD(lr=0.01),'mean_squared_error' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9844
# Epoch 2/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9846
# Epoch 3/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9848
# Epoch 4/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9848
# Epoch 5/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9848
# Epoch 6/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9849
# Epoch 7/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9849
# Epoch 8/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0022 - accuracy: 0.9849
# Epoch 9/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0021 - accuracy: 0.9850
# Epoch 10/100
# ...

# %%
model.compile(SGD(lr=0.01),'categorical_crossentropy' ,metrics=['accuracy'])
model.fit(train_images , train_labels , epochs = 100 )
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0610 - accuracy: 0.9858
# Epoch 2/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0548 - accuracy: 0.9861
# Epoch 3/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0511 - accuracy: 0.9863
# Epoch 4/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0487 - accuracy: 0.9867
# Epoch 5/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0470 - accuracy: 0.9869
# Epoch 6/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0458 - accuracy: 0.9872
# Epoch 7/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0449 - accuracy: 0.9873
# Epoch 8/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0442 - accuracy: 0.9875
# Epoch 9/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0435 - accuracy: 0.9875
# Epoch 10/100
# ...
